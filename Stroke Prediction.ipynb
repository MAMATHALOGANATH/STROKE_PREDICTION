# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
plt.rcParams['figure.figsize'] = (5, 5)

# %%
data = pd.read_csv(r'C:\Users\sloga\Desktop\ml project\healthcare-dataset-stroke-data.csv')

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data.hist(figsize=(15,15))
plt.show()

# %%
numeric_columns=['age','hypertension','heart_disease','avg_glucose_level','bmi']
sns.heatmap(data[numeric_columns].corr(),annot=True,cmap='terrain',linewidths=0)
fig=plt.gcf()
fig.set_size_inches(9,7)
plt.show()

# %%
data_numerical=data[['age','avg_glucose_level','bmi']]
fig, ax = plt.subplots(figsize = (12,6))
fig.patch.set_facecolor('#f6f5f7')
ax.set_facecolor('#f6f5f5')
sns.kdeplot(data=data_numerical,shade=True,palette='rocket') # Distributions
# removing spines
for i in ["top","right"]:
    ax.spines[i].set_visible(False)
plt.title('Kde Plots for age, avg_glucose_level and bmi',weight='bold')
# Out:
# Text(0.5, 1.0, 'Kde Plots for age, avg_glucose_level and bmi')

# %%
fig = plt.figure(figsize=(20,13))
gs = fig.add_gridspec(3,3)
gs.update(wspace=0.4, hspace=0.4)
# adding figures
ax0 = fig.add_subplot(gs[0,0])
ax1 = fig.add_subplot(gs[0,1])
ax2 = fig.add_subplot(gs[1,0])
ax3 = fig.add_subplot(gs[1,1])
ax4 = fig.add_subplot(gs[2,0])
ax5 = fig.add_subplot(gs[2,1])
axes=[ax0,ax1,ax2,ax3,ax4,ax5]
background_color = '#f6f5f7'
for i in axes:
    i.set_facecolor(background_color)
fig.patch.set_facecolor(background_color) 
sns.kdeplot(ax=ax0,x=data.loc[data['stroke']==1]['age'],color='crimson',label='Stroke',shade=True)
sns.kdeplot(ax=ax0,x=data.loc[data['stroke']==0]['age'],color='coral',label='No Stroke',shade=True)
ax0.legend(loc = 'upper left')
ax0.grid(linestyle='--', axis='y')

ax1.text(0.5,0.5,'Distribution of Age wrt Stroke',horizontalalignment = 'center',verticalalignment = 'center',fontsize = 18,fontfamily='serif')

sns.kdeplot(ax=ax2,x=data.loc[data['stroke']==1]['avg_glucose_level'],color='crimson',label='Stroke',shade=True)
sns.kdeplot(ax=ax2,x=data.loc[data['stroke']==0]['avg_glucose_level'],color='coral',label='No Stroke',shade=True)
ax2.legend(loc = 'upper right')
ax2.grid(linestyle='--', axis='y')

ax3.text(0.5,0.5,'Distribution of Glucose level\n wrt Stroke',horizontalalignment = 'center',verticalalignment = 'center',fontsize = 18,fontfamily='serif')


sns.kdeplot(ax=ax4,x=data.loc[data['stroke']==1]['bmi'],color='crimson',label='Stroke',shade=True)
sns.kdeplot(ax=ax4,x=data.loc[data['stroke']==0]['bmi'],color='coral',label='No Stroke',shade=True)
ax4.legend(loc = 'upper right')
ax4.grid(linestyle='--', axis='y')

ax5.text(0.5,0.5,'Distribution of BMI\n wrt Stroke',horizontalalignment = 'center',verticalalignment = 'center',fontsize = 18,fontfamily='serif')
# removing labels

axes1=[ax1,ax3,ax5]
for i in axes1:
    i.spines["bottom"].set_visible(False)
    i.spines["left"].set_visible(False)
    i.set_xlabel("")
    i.set_ylabel("")
    i.set_xticklabels([])
    i.set_yticklabels([])
    i.tick_params(left=False, bottom=False)
# removing spines of figures
for i in ["top","left","right"]:
    ax0.spines[i].set_visible(False)
    ax1.spines[i].set_visible(False)
    ax2.spines[i].set_visible(False)
    ax3.spines[i].set_visible(False)
    ax4.spines[i].set_visible(False)
    ax5.spines[i].set_visible(False)

# %%
data_cat=data[['gender', 'hypertension', 'heart_disease', 'ever_married','work_type', 'Residence_type', 
                       'smoking_status']]
fig=plt.figure(figsize=(20,23))
background_color = '#f6f5f7'
fig.patch.set_facecolor(background_color) 
for indx,val in enumerate(data_cat.columns):
    ax=plt.subplot(4,2,indx+1)
    ax.set_facecolor(background_color)
    ax.set_title(val,fontweight='bold',fontfamily='serif')
    for i in ['top','right']:
        ax.spines[i].set_visible(False)
    ax.grid(linestyle=':',axis='y')
    sns.countplot(data_cat[val],palette='OrRd_r',hue=data['stroke'])
# Out:
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\sloga\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # LETS FILL NULL VALUES

# %%
data['bmi'].value_counts()
# Out:
# 28.7    41
# 28.4    38
# 27.7    37
# 27.6    37
# 26.7    37
#         ..
# 48.0     1
# 49.4     1
# 47.4     1
# 46.6     1
# 54.0     1
# Name: bmi, Length: 418, dtype: int64

# %%
data['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %%
data['bmi'].fillna(data['bmi'].mean(),inplace=True)

# %%
data['bmi'].describe()
# Out:
# count    5110.000000
# mean       28.893237
# std         7.698018
# min        10.300000
# 25%        23.800000
# 50%        28.400000
# 75%        32.800000
# max        97.600000
# Name: bmi, dtype: float64

# %%
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data.drop('id',axis=1,inplace=True)

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0             Urban             228.69  36.600000  formerly smoked       1
# 1             Rural             202.21  28.893237     never smoked       1
# 2             Rural             105.92  32.500000     never smoked       1
# 3             Urban             171.23  34.400000           smokes       1
# 4             Rural             174.12  24.000000     never smoked       1
# ...             ...                ...        ...              ...     ...
# 5105          Urban              83.75  28.893237     never smoked       0
# 5106          Urban             125.20  40.000000     never smoked       0
# 5107          Rural              82.99  30.600000     never smoked       0
# 5108          Rural             166.29  25.600000  formerly smoked       0
# 5109          Urban              85.28  26.200000          Unknown       0
#
# [5110 rows x 11 columns]

# %% [markdown]
# # OUTLIER REMOVATION

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=800, facecolor='w', edgecolor='k')

# %%
data.plot(kind='box')
plt.xticks(rotation=90)
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  [Text(1, 0, 'age'),
#   Text(2, 0, 'hypertension'),
#   Text(3, 0, 'heart_disease'),
#   Text(4, 0, 'avg_glucose_level'),
#   Text(5, 0, 'bmi'),
#   Text(6, 0, 'stroke')])

# %%
data['avg_glucose_level'].describe()
# Out:
# count    5110.000000
# mean      106.147677
# std        45.283560
# min        55.120000
# 25%        77.245000
# 50%        91.885000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %%
data[data['avg_glucose_level']>114.09999]
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5071    Male  81.0             0              0          Yes        Private
# 5076  Female  34.0             0              0          Yes        Private
# 5086  Female  51.0             0              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0             Urban             228.69  36.600000  formerly smoked       1
# 1             Rural             202.21  28.893237     never smoked       1
# 3             Urban             171.23  34.400000           smokes       1
# 4             Rural             174.12  24.000000     never smoked       1
# 5             Urban             186.21  29.000000  formerly smoked       1
# ...             ...                ...        ...              ...     ...
# 5071          Rural             135.32  35.800000          Unknown       0
# 5076          Rural             174.37  23.000000     never smoked       0
# 5086          Urban             152.56  21.800000          Unknown       0
# 5106          Urban             125.20  40.000000     never smoked       0
# 5108          Rural             166.29  25.600000  formerly smoked       0
#
# [1277 rows x 11 columns]

# %%
data['avg_glucose_level'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       228.69
# 1       202.21
# 2       105.92
# 3       171.23
# 4       174.12
#          ...
# 5105     83.75
# 5106    125.20
# 5107     82.99
# 5108    166.29
# 5109     85.28
# Name: avg_glucose_level, Length: 5110, dtype: float64>

# %% [markdown]
# # LABEL ENCODING

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0             Urban             228.69  36.600000  formerly smoked       1
# 1             Rural             202.21  28.893237     never smoked       1
# 2             Rural             105.92  32.500000     never smoked       1
# 3             Urban             171.23  34.400000           smokes       1
# 4             Rural             174.12  24.000000     never smoked       1
# ...             ...                ...        ...              ...     ...
# 5105          Urban              83.75  28.893237     never smoked       0
# 5106          Urban             125.20  40.000000     never smoked       0
# 5107          Rural              82.99  30.600000     never smoked       0
# 5108          Rural             166.29  25.600000  formerly smoked       0
# 5109          Urban              85.28  26.200000          Unknown       0
#
# [5110 rows x 11 columns]

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0          Urban             228.69  36.600000  formerly smoked       1
# 1          Rural             202.21  28.893237     never smoked       1
# 2          Rural             105.92  32.500000     never smoked       1
# 3          Urban             171.23  34.400000           smokes       1
# 4          Rural             174.12  24.000000     never smoked       1

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
gender=enc.fit_transform(data['gender'])

# %%
smoking_status=enc.fit_transform(data['smoking_status'])

# %%
work_type=enc.fit_transform(data['work_type'])
Residence_type=enc.fit_transform(data['Residence_type'])
ever_married=enc.fit_transform(data['ever_married'])

# %%
data['work_type']=work_type

# %%
data['ever_married']=ever_married
data['Residence_type']=Residence_type
data['smoking_status']=smoking_status
data['gender']=gender

# %%
data
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# 0                  1             228.69  36.600000               1       1
# 1                  0             202.21  28.893237               2       1
# 2                  0             105.92  32.500000               2       1
# 3                  1             171.23  34.400000               3       1
# 4                  0             174.12  24.000000               2       1
# ...              ...                ...        ...             ...     ...
# 5105               1              83.75  28.893237               2       0
# 5106               1             125.20  40.000000               2       0
# 5107               0              82.99  30.600000               2       0
# 5108               0             166.29  25.600000               1       0
# 5109               1              85.28  26.200000               0       0
#
# [5110 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   int32
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   int32
#  5   work_type          5110 non-null   int32
#  6   Residence_type     5110 non-null   int32
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                5110 non-null   float64
#  9   smoking_status     5110 non-null   int32
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int32(5), int64(3)
# memory usage: 339.5 KB

# %% [markdown]
# # SPLITTING THE DATA FOR TRAIN AND TEST

# %% [markdown]
# X ---train_X,test_X 80/20

# %% [markdown]
# Y ---train_Y,test_Y

# %%
X=data.drop('stroke',axis=1)

# %%
X.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          2
# 1       0  61.0             0              0             1          3
# 2       1  80.0             0              1             1          2
# 3       0  49.0             0              0             1          2
# 4       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level        bmi  smoking_status
# 0               1             228.69  36.600000               1
# 1               0             202.21  28.893237               2
# 2               0             105.92  32.500000               2
# 3               1             171.23  34.400000               3
# 4               0             174.12  24.000000               2

# %%
Y=data['stroke']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
X_train
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 2285       1  49.0             0              0             1          2
# 4733       1  67.0             0              0             1          2
# 3905       1  78.0             0              0             1          2
# 4700       1  47.0             0              0             1          2
# 4939       0  59.0             0              0             1          2
# ...      ...   ...           ...            ...           ...        ...
# 1180       0  62.0             0              0             1          2
# 3441       0  59.0             0              0             1          3
# 1344       1  47.0             0              0             1          2
# 4623       1  25.0             0              0             1          0
# 1289       0  80.0             0              0             1          3
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 2285               0              79.64  28.893237               3
# 4733               0              83.16  25.500000               1
# 3905               1             208.85  24.400000               1
# 4700               0             110.14  30.500000               3
# 4939               1              71.08  28.100000               2
# ...              ...                ...        ...             ...
# 1180               0              82.57  36.000000               1
# 3441               1              90.06  28.900000               3
# 1344               0              86.37  39.200000               3
# 4623               1             166.38  23.100000               2
# 1289               0              72.61  27.600000               2
#
# [4088 rows x 10 columns]

# %%
Y_train
# Out:
# 2285    0
# 4733    0
# 3905    0
# 4700    0
# 4939    0
#        ..
# 1180    0
# 3441    0
# 1344    0
# 4623    0
# 1289    0
# Name: stroke, Length: 4088, dtype: int64

# %%
X_test
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 2413       0  58.00             0              0             1          2
# 1141       1  57.00             0              0             1          2
# 146        1  65.00             0              0             1          3
# 3883       0   1.64             0              0             0          4
# 1044       0  79.00             0              0             1          0
# ...      ...    ...           ...            ...           ...        ...
# 2261       1  59.00             0              0             1          2
# 4712       1  57.00             0              0             1          2
# 4971       0  63.00             0              0             1          2
# 2224       1  57.00             0              0             1          2
# 4825       0  14.00             0              0             0          4
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 2413               0             100.42  39.500000               3
# 1141               0              90.06  29.800000               0
# 146                1              68.43  28.893237               1
# 3883               1              69.89  18.100000               0
# 1044               1              93.89  30.400000               2
# ...              ...                ...        ...             ...
# 2261               1              60.35  25.900000               1
# 4712               1              93.04  29.200000               2
# 4971               1              57.06  37.900000               2
# 2224               0              76.28  31.400000               1
# 4825               1              71.80  18.800000               0
#
# [1022 rows x 10 columns]

# %%
Y_test
# Out:
# 2413    0
# 1141    0
# 146     1
# 3883    0
# 1044    0
#        ..
# 2261    0
# 4712    0
# 4971    0
# 2224    0
# 4825    0
# Name: stroke, Length: 1022, dtype: int64

# %% [markdown]
# # NORMALIZE

# %%
data.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  5110.000000  5110.000000   5110.000000    5110.000000   5110.000000
# mean      0.414286    43.226614      0.097456       0.054012      0.656164
# std       0.493044    22.612647      0.296607       0.226063      0.475034
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       2.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  5110.000000     5110.000000        5110.000000  5110.000000
# mean      2.167710        0.508023         106.147677    28.893237
# std       1.090293        0.499985          45.283560     7.698018
# min       0.000000        0.000000          55.120000    10.300000
# 25%       2.000000        0.000000          77.245000    23.800000
# 50%       2.000000        1.000000          91.885000    28.400000
# 75%       3.000000        1.000000         114.090000    32.800000
# max       4.000000        1.000000         271.740000    97.600000
#
#        smoking_status       stroke
# count     5110.000000  5110.000000
# mean         1.376908     0.048728
# std          1.071534     0.215320
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          2.000000     0.000000
# 75%          2.000000     0.000000
# max          3.000000     1.000000

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %%
import pickle
import os

# %%
X_train_std
# Out:
# array([[ 1.19359699,  0.2521852 , -0.33069968, ..., -0.58626884,
#          0.00238781,  1.51158251],
#        [ 1.19359699,  1.04686385, -0.33069968, ..., -0.50843521,
#         -0.44065504, -0.35191245],
#        [ 1.19359699,  1.5325008 , -0.33069968, ...,  2.27080023,
#         -0.58427812, -0.35191245],
#        ...,
#        [ 1.19359699,  0.16388757, -0.33069968, ..., -0.43745625,
#          1.34810513,  1.51158251],
#        [ 1.19359699, -0.80738634, -0.33069968, ...,  1.33171097,
#         -0.75401449,  0.57983503],
#        [-0.83780372,  1.62079843, -0.33069968, ..., -0.74171498,
#         -0.16646553,  0.57983503]])

# %%
X_train_std
# Out:
# array([[ 1.19359699,  0.2521852 , -0.33069968, ..., -0.58626884,
#          0.00238781,  1.51158251],
#        [ 1.19359699,  1.04686385, -0.33069968, ..., -0.50843521,
#         -0.44065504, -0.35191245],
#        [ 1.19359699,  1.5325008 , -0.33069968, ...,  2.27080023,
#         -0.58427812, -0.35191245],
#        ...,
#        [ 1.19359699,  0.16388757, -0.33069968, ..., -0.43745625,
#          1.34810513,  1.51158251],
#        [ 1.19359699, -0.80738634, -0.33069968, ...,  1.33171097,
#         -0.75401449,  0.57983503],
#        [-0.83780372,  1.62079843, -0.33069968, ..., -0.74171498,
#         -0.16646553,  0.57983503]])

# %% [markdown]
# # SAVE THE SCALER OBJECT

# %%
import pickle
import os

# %%
scaler_path=os.path.join(r'C:/Users/sloga/Desktop/ml project/','models/scaler.pkl')
with open(scaler_path,'wb') as scaler_file:
    pickle.dump(std,scaler_file)

# %%
#X_train_std

# %%
#X_test_std

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
dt=DecisionTreeClassifier()

# %%
tf=dt.fit(X_train_std,Y_train)
tf
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(100,100))
tree.plot_tree(tf,filled=True)
# Out:
# [Text(2758.4551725819033, 5306.571428571428, 'X[1] <= 1.069\ngini = 0.087\nsamples = 4088\nvalue = [3901, 187]'),
#  Text(1430.4780128705147, 5047.714285714286, 'X[1] <= 0.583\ngini = 0.041\nsamples = 3398\nvalue = [3327, 71]'),
#  Text(742.7032956318253, 4788.857142857143, 'X[2] <= 1.347\ngini = 0.021\nsamples = 2790\nvalue = [2761, 29]'),
#  Text(376.95105304212166, 4530.0, 'X[1] <= -0.256\ngini = 0.016\nsamples = 2660\nvalue = [2639, 21]'),
#  Text(92.85491419656786, 4271.142857142857, 'X[1] <= -1.851\ngini = 0.002\nsamples = 1602\nvalue = [1600, 2]'),
#  Text(46.42745709828393, 4012.2857142857147, 'X[8] <= -0.258\ngini = 0.03\nsamples = 65\nvalue = [64, 1]'),
#  Text(23.213728549141965, 3753.4285714285716, 'gini = 0.0\nsamples = 60\nvalue = [60, 0]'),
#  Text(69.6411856474259, 3753.4285714285716, 'X[7] <= -0.762\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(46.42745709828393, 3494.5714285714284, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(92.85491419656786, 3494.5714285714284, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(139.2823712948518, 4012.2857142857147, 'X[9] <= 1.046\ngini = 0.001\nsamples = 1537\nvalue = [1536, 1]'),
#  Text(116.06864274570982, 3753.4285714285716, 'gini = 0.0\nsamples = 1349\nvalue = [1349, 0]'),
#  Text(162.49609984399376, 3753.4285714285716, 'X[7] <= -0.662\ngini = 0.011\nsamples = 188\nvalue = [187, 1]'),
#  Text(139.2823712948518, 3494.5714285714284, 'X[7] <= -0.671\ngini = 0.042\nsamples = 47\nvalue = [46, 1]'),
#  Text(116.06864274570982, 3235.714285714286, 'gini = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(162.49609984399376, 3235.714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(185.70982839313572, 3494.5714285714284, 'gini = 0.0\nsamples = 141\nvalue = [141, 0]'),
#  Text(661.0471918876755, 4271.142857142857, 'X[8] <= 0.401\ngini = 0.035\nsamples = 1058\nvalue = [1039, 19]'),
#  Text(506.7121684867395, 4012.2857142857147, 'X[8] <= 0.388\ngini = 0.047\nsamples = 665\nvalue = [649, 16]'),
#  Text(337.3244929797192, 3753.4285714285716, 'X[8] <= -0.46\ngini = 0.044\nsamples = 660\nvalue = [645, 15]'),
#  Text(232.13728549141965, 3494.5714285714284, 'X[1] <= -0.211\ngini = 0.009\nsamples = 219\nvalue = [218, 1]'),
#  Text(208.92355694227768, 3235.714285714286, 'X[4] <= -0.328\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(185.70982839313572, 2976.857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(232.13728549141965, 2976.857142857143, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text
285714284, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(5533.572542901716, 4271.142857142857, 'X[1] <= 1.621\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5510.358814352574, 4012.2857142857147, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5556.786271450858, 4012.2857142857147, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
print(tree.export_text(tf))
# Out:
# |--- feature_1 <= 1.07
# |   |--- feature_1 <= 0.58
# |   |   |--- feature_2 <= 1.35
# |   |   |   |--- feature_1 <= -0.26
# |   |   |   |   |--- feature_1 <= -1.85
# |   |   |   |   |   |--- feature_8 <= -0.26
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  -0.26
# |   |   |   |   |   |   |--- feature_7 <= -0.76
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  -0.76
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  -1.85
# |   |   |   |   |   |--- feature_9 <= 1.05
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_9 >  1.05
# |   |   |   |   |   |   |--- feature_7 <= -0.66
# |   |   |   |   |   |   |   |--- feature_7 <= -0.67
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  -0.67
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  -0.66
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  -0.26
# |   |   |   |   |--- feature_8 <= 0.40
# |   |   |   |   |   |--- feature_8 <= 0.39
# |   |   |   |   |   |   |--- feature_8 <= -0.46
# |   |   |   |   |   |   |   |--- feature_1 <= -0.21
# |   |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  -0.21
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  -0.46
# |   |   |   |   |   |   |   |--- feature_8 <= -0.42
# |   |   |   |   |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= -0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  -0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  -0.42
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.03
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.04
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.04
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.03
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.54
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.54
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.39
# |   |   |   |   |   |   |--- feature_7 <= 0.01
# |   |   |   |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_7 >  0.01
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  0.40
# |   |   |   |   |   |--- feature_7 <= 0.82
# |   |   |   |   |   |   |--- feature_7 <= -0.92
# |   |   |   |   |   |   |   |--- feature_7 <= -0.93
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  -0.93
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  -0.92
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  0.82
# |   |   |   |   |   |   |--- feature_7 <= 0.85
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  0.85
# |   |   |   |   |   |   |   |--- feature_7 <= 1.45
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.37
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.37
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  1.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_2 >  1.35
# |   |   |   |--- feature_7 <= 2.75
# |   |   |   |   |--- feature_1 <= 0.27
# |   |   |   |   |   |--- feature_7 <= -1.04
# |   |   |   |   |   |   |--- feature_8 <= 1.36
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_8 >  1.36
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  -1.04
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  0.27
# |   |   |   |   |   |--- feature_1 <= 0.36
# |   |   |   |   |   |   |--- feature_8 <= 1.67
# |   |   |   |   |   |   |   |--- feature_9 <= 1.05
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.74
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.74
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.43
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_9 >  1.05
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  1.67
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  0.36
# |   |   |   |   |   |   |--- feature_3 <= 2.00
# |   |   |   |   |   |   |   |--- feature_8 <= -0.15
# |   |   |   |   |   |   |   |   |--- feature_8 <= -0.19
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  -0.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  -0.15
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  2.00
# |   |   |   |   |   |   |   |--- feature_1 <= 0.47
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.47
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_7 >  2.75
# |   |   |   |   |--- feature_1 <= 0.41
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  0.41
# |   |   |   |   |   |--- class: 0
# |   |--- feature_1 >  0.58
# |   |   |--- feature_3 <= 2.00
# |   |   |   |--- feature_1 <= 0.67
# |   |   |   |   |--- feature_9 <= -0.82
# |   |   |   |   |   |--- feature_8 <= -0.06
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  -0.06
# |   |   |   |   |   |   |--- feature_7 <= -0.42
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  -0.42
# |   |   |   |   |   |   |   |--- feature_8 <= 0.02
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.09
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.09
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  0.02
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.28
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.28
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_9 >  -0.82
# |   |   |   |   |   |--- feature_7 <= 2.01
# |   |   |   |   |   |   |--- feature_7 <= -0.52
# |   |   |   |   |   |   |   |--- feature_7 <= -0.53
# |   |   |   |   |   |   |   |   |--- feature_8 <= -0.16
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  -0.16
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  -0.53
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  -0.52
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  2.01
# |   |   |   |   |   |   |--- feature_9 <= 1.05
# |   |   |   |   |   |   |   |--- feature_7 <= 2.04
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  2.04
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_9 >  1.05
# |   |   |   |   |   |   |   |--- feature_8 <= 0.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  0.45
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  0.67
# |   |   |   |   |--- feature_7 <= -0.19
# |   |   |   |   |   |--- feature_8 <= -1.00
# |   |   |   |   |   |   |--- feature_8 <= -1.02
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  -1.02
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  -1.00
# |   |   |   |   |   |   |--- feature_2 <= 1.35
# |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |--- feature_8 <= 1.12
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  1.12
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  1.35
# |   |   |   |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |   |   |   |--- feature_8 <= -0.10
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  -0.10
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_7 >  -0.19
# |   |   |   |   |   |--- feature_7 <= -0.19
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_7 >  -0.19
# |   |   |   |   |   |   |--- feature_9 <= 0.11
# |   |   |   |   |   |   |   |--- feature_1 <= 0.85
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.72
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.72
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.85
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.62
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.62
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 2.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  2.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_9 >  0.11
# |   |   |   |   |   |   |   |--- feature_8 <= -0.64
# |   |   |   |   |   |   |   |   |--- feature_7 <= 2.34
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.67
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  2.34
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  -0.64
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  2.00
# |   |   |   |--- feature_9 <= -0.82
# |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_9 >  -0.82
# |   |   |   |   |--- feature_8 <= 0.88
# |   |   |   |   |   |--- feature_8 <= 0.72
# |   |   |   |   |   |   |--- feature_9 <= 1.05
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_9 >  1.05
# |   |   |   |   |   |   |   |--- feature_8 <= -0.26
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  -0.26
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.83
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.83
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.72
# |   |   |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  0.88
# |   |   |   |   |   |--- feature_8 <= 1.19
# |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |--- feature_5 <= -1.06
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_5 >  -1.06
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  1.19
# |   |   |   |   |   |   |--- class: 0
# |--- feature_1 >  1.07
# |   |--- feature_1 <= 1.42
# |   |   |--- feature_7 <= 3.35
# |   |   |   |--- feature_7 <= 2.45
# |   |   |   |   |--- feature_8 <= 1.05
# |   |   |   |   |   |--- feature_8 <= 0.99
# |   |   |   |   |   |   |--- feature_1 <= 1.33
# |   |   |   |   |   |   |   |--- feature_7 <= 1.94
# |   |   |   |   |   |   |   |   |--- feature_7 <= -0.18
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.19
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  -0.18
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  1.94
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.99
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.42
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.99
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  1.33
# |   |   |   |   |   |   |   |--- feature_7 <= -0.60
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.21
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.03
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.03
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.21
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  -0.60
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.82
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.82
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.99
# |   |   |   |   |   |   |--- feature_5 <= -1.06
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  -1.06
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  1.05
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_7 >  2.45
# |   |   |   |   |--- feature_8 <= 0.23
# |   |   |   |   |   |--- feature_7 <= 2.56
# |   |   |   |   |   |   |--- feature_7 <= 2.51
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_7 >  2.51
# |   |   |   |   |   |   |   |--- feature_1 <= 1.25
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  1.25
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_7 >  2.56
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  0.23
# |   |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |   |--- feature_7 <= 2.73
# |   |   |   |   |   |   |   |--- feature_7 <= 2.63
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.43
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.43
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  2.63
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_7 >  2.73
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_7 >  3.35
# |   |   |   |--- class: 1
# |   |--- feature_1 >  1.42
# |   |   |--- feature_8 <= 0.62
# |   |   |   |--- feature_7 <= -0.06
# |   |   |   |   |--- feature_7 <= -0.29
# |   |   |   |   |   |--- feature_6 <= -0.02
# |   |   |   |   |   |   |--- feature_8 <= -0.07
# |   |   |   |   |   |   |   |--- feature_8 <= -0.43
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.51
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.51
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= -1.06
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  -1.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  -0.43
# |   |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  -0.07
# |   |   |   |   |   |   |   |--- feature_9 <= -0.82
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_9 >  -0.82
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.60
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.60
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_6 >  -0.02
# |   |   |   |   |   |   |--- feature_8 <= 0.00
# |   |   |   |   |   |   |   |--- feature_8 <= -0.01
# |   |   |   |   |   |   |   |   |--- feature_8 <= -0.64
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  -0.64
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_8 >  -0.01
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.58
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= -0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  -0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.58
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_7 >  -0.29
# |   |   |   |   |   |--- feature_8 <= -0.95
# |   |   |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  -0.95
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_7 >  -0.06
# |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |--- feature_7 <= 0.20
# |   |   |   |   |   |   |--- feature_8 <= 0.25
# |   |   |   |   |   |   |   |--- feature_8 <= 0.04
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.55
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.55
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  0.04
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  0.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_7 >  0.20
# |   |   |   |   |   |   |--- feature_8 <= -0.21
# |   |   |   |   |   |   |   |--- feature_8 <= -0.77
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.81
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.81
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  -0.77
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.82
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.82
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  -0.21
# |   |   |   |   |   |   |   |--- feature_7 <= 0.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  0.45
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.77
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_3 >  2.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.24
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |--- feature_8 <= 0.61
# |   |   |   |   |   |   |--- feature_7 <= 0.01
# |   |   |   |   |   |   |   |--- feature_1 <= 1.51
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  1.51
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.60
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.60
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  0.01
# |   |   |   |   |   |   |   |--- feature_7 <= 3.17
# |   |   |   |   |   |   |   |   |--- feature_8 <= -0.08
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.31
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= -0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  -0.31
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  -0.08
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.55
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  3.17
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.41
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.41
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_8 >  0.61
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_8 >  0.62
# |   |   |   |--- feature_8 <= 2.13
# |   |   |   |   |--- feature_7 <= -0.65
# |   |   |   |   |   |--- feature_7 <= -0.68
# |   |   |   |   |   |   |--- feature_5 <= 0.31
# |   |   |   |   |   |   |   |--- feature_4 <= -0.33
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  -0.33
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  0.31
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  -0.68
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_7 >  -0.65
# |   |   |   |   |   |--- feature_7 <= 2.74
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  2.74
# |   |   |   |   |   |   |--- feature_7 <= 2.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  2.80
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_8 >  2.13
# |   |   |   |   |--- feature_1 <= 1.62
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_1 >  1.62
# |   |   |   |   |   |--- class: 0

# %%
dt.feature_importances_
# Out:
# array([0.03354656, 0.1857493 , 0.01665584, 0.02363083, 0.03290826,
#        0.05292164, 0.04964002, 0.27231159, 0.28414839, 0.04848758])

# %%
X_train.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
Y_pred=dt.predict(X_test_std)

# %%
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Y_test
# Out:
# 2413    0
# 1141    0
# 146     1
# 3883    0
# 1044    0
#        ..
# 2261    0
# 4712    0
# 4971    0
# 2224    0
# 4825    0
# Name: stroke, Length: 1022, dtype: int64

# %%
X_test
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 2413       0  58.00             0              0             1          2
# 1141       1  57.00             0              0             1          2
# 146        1  65.00             0              0             1          3
# 3883       0   1.64             0              0             0          4
# 1044       0  79.00             0              0             1          0
# ...      ...    ...           ...            ...           ...        ...
# 2261       1  59.00             0              0             1          2
# 4712       1  57.00             0              0             1          2
# 4971       0  63.00             0              0             1          2
# 2224       1  57.00             0              0             1          2
# 4825       0  14.00             0              0             0          4
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 2413               0             100.42  39.500000               3
# 1141               0              90.06  29.800000               0
# 146                1              68.43  28.893237               1
# 3883               1              69.89  18.100000               0
# 1044               1              93.89  30.400000               2
# ...              ...                ...        ...             ...
# 2261               1              60.35  25.900000               1
# 4712               1              93.04  29.200000               2
# 4971               1              57.06  37.900000               2
# 2224               0              76.28  31.400000               1
# 4825               1              71.80  18.800000               0
#
# [1022 rows x 10 columns]

# %%
#compare using matrix

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt=accuracy_score(Y_test,Y_pred)

# %%
ac_dt
# Out:
# 0.9021526418786693

# %%
import joblib
model_path=os.path.join(r'C:/Users/sloga/Desktop/ml project/','models/dt.sav')
joblib.dump(dt,model_path)
# Out:
# ['C:/Users/sloga/Desktop/ml project/models/dt.sav']

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       960
#            1       0.13      0.11      0.12        62
#
#     accuracy                           0.90      1022
#    macro avg       0.54      0.53      0.54      1022
# weighted avg       0.89      0.90      0.90      1022

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(tf,X_test_std,Y_test,cmap='Blues',values_format ='.3g')
disp.confusion_matrix
# Out:
# array([[915,  45],
#        [ 55,   7]], dtype=int64)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
lr=LogisticRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
Y_pred_lr
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Y_test
# Out:
# 2413    0
# 1141    0
# 146     1
# 3883    0
# 1044    0
#        ..
# 2261    0
# 4712    0
# 4971    0
# 2224    0
# 4825    0
# Name: stroke, Length: 1022, dtype: int64

# %%
confusion_matrix(Y_test,Y_pred)
# Out:
# array([[915,  45],
#        [ 55,   7]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
disp=plot_confusion_matrix(lr,X_test,Y_test,cmap='Blues',values_format='.3g')

# %%
ac_lr=accuracy_score(Y_test,Y_pred_lr)

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       960
#            1       0.13      0.11      0.12        62
#
#     accuracy                           0.90      1022
#    macro avg       0.54      0.53      0.54      1022
# weighted avg       0.89      0.90      0.90      1022

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier()

# %%
X_train_std
# Out:
# array([[ 1.19359699,  0.2521852 , -0.33069968, ..., -0.58626884,
#          0.00238781,  1.51158251],
#        [ 1.19359699,  1.04686385, -0.33069968, ..., -0.50843521,
#         -0.44065504, -0.35191245],
#        [ 1.19359699,  1.5325008 , -0.33069968, ...,  2.27080023,
#         -0.58427812, -0.35191245],
#        ...,
#        [ 1.19359699,  0.16388757, -0.33069968, ..., -0.43745625,
#          1.34810513,  1.51158251],
#        [ 1.19359699, -0.80738634, -0.33069968, ...,  1.33171097,
#         -0.75401449,  0.57983503],
#        [-0.83780372,  1.62079843, -0.33069968, ..., -0.74171498,
#         -0.16646553,  0.57983503]])

# %%
Y_pred=knn.predict(X_test_std)

# %%
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
ac_knn=accuracy_score(Y_test,Y_pred)

# %%
ac_knn
# Out:
# 0.9344422700587084

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97       960
#            1       0.00      0.00      0.00        62
#
#     accuracy                           0.93      1022
#    macro avg       0.47      0.50      0.48      1022
# weighted avg       0.88      0.93      0.91      1022

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(knn,X_test_std,Y_test,cmap='Blues',values_format ='.3g')
disp.confusion_matrix
# Out:
# array([[955,   5],
#        [ 62,   0]], dtype=int64)

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train_std,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred=rf.predict(X_test_std)

# %%
ac_rf=accuracy_score(Y_test,Y_pred)

# %%
ac_rf
# Out:
# 0.9373776908023483

# %%
ac_knn
# Out:
# 0.9344422700587084

# %%
ac_dt
# Out:
# 0.9021526418786693

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       960
#            1       0.00      0.00      0.00        62
#
#     accuracy                           0.94      1022
#    macro avg       0.47      0.50      0.48      1022
# weighted avg       0.88      0.94      0.91      1022

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(rf,X_test_std,Y_test,cmap='Blues',values_format ='.3g')
disp.confusion_matrix
# Out:
# array([[958,   2],
#        [ 62,   0]], dtype=int64)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(X_train_std,Y_train)
# Out:
# SVC()

# %%
Y_pred=sv.predict(X_test_std)

# %%
ac_sv=accuracy_score(Y_test,Y_pred)

# %%
ac_sv
# Out:
# 0.9393346379647749

# %%
ac_lr
# Out:
# 0.9383561643835616

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       960
#            1       0.00      0.00      0.00        62
#
#     accuracy                           0.94      1022
#    macro avg       0.47      0.50      0.48      1022
# weighted avg       0.88      0.94      0.91      1022
# C:\Users\sloga\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sloga\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\sloga\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(sv,X_test_std,Y_test,cmap='Blues',values_format ='.3g')
disp.confusion_matrix
# Out:
# array([[960,   0],
#        [ 62,   0]], dtype=int64)

# %%
plt.bar(['Decision Tree','Logistic','KNN','Random Forest','SVM'],[ac_dt,ac_lr,ac_knn,ac_rf,ac_sv])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.xticks(rotation=90)

plt.show()
